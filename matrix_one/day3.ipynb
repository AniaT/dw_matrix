# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]
from google.colab import drive
import pandas as pd
import numpy as np

# %%
#!dw configure

# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
#drive.mount("/content/drive")

# %%
ls
# Out:
# data/  HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/dw_matrix'
# /content/drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix

# %%
ls
# Out:
# dw_matrix/

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix'
# /content/drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix/dw_matrix/"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix/dw_matrix/'
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
cd dw_matrix/
# Out:
# [Errno 2] No such file or directory: 'dw_matrix/'
# /content/drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix

# %%
ls
# Out:
# HelloGitHub.ipynb  LICENSE  README.md

# %%
ls
# Out:
# HelloGitHub.ipynb  LICENSE  README.md

# %%
ls
# Out:
# HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
ls matrix_one
# Out:
# day3.ipynb

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
echo 'data' > .gitignore
# Out:
#   File "<ipython-input-17-190efbcadad9>", line 1
#     echo 'data' > .gitignore
#               ^
# SyntaxError: invalid syntax

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data=dw.load_dataset('datafiniti/mens-shoe-prices')
data.dataframes['7004_1']
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a41eb9671d20> in <module>()
#       1 data=dw.load_dataset('datafiniti/mens-shoe-prices')
#       2 data.dataframes['7004_1']
# ----> 3 df.shape
#
# NameError: name 'df' is not defined

# %%
df =  data.dataframes['7004_1']

# %%
df.shape
# Out:
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id       asins         brand  ...  vin websiteids  weight
# 8846   AVpe3ovWLJeJML43xE4s         NaN          PUMA  ...  NaN        NaN     NaN
# 17849  AVpfdSq11cnluZ0-lFcW  B00BI7CUI4         Julbo  ...  NaN        NaN     NaN
# 6030   AVpfXAuxLJeJML437zeb  B00MRGWKYO        Jordan  ...  NaN        NaN     NaN
# 16749  AVpfToNz1cnluZ0-iQmC         NaN   Blue Tongue  ...  NaN        NaN     NaN
# 15533  AVpfYKG3LJeJML438Jf1         NaN  Under Armour  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# New with box                                          0.000155
# new                                                   0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# New without tags                                      0.000052
# Shoes.com                                             0.000052
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd = df[ df.prices_currency == 'USD' ].copy()

# %%
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
filter_max = np.percentile( df_usd['prices_amountmin'],99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[df_usd['prices_amountmin'] < filter_max ]
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
ls
# Out:
# data/  HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
df.to_csv('data/shoes_prices.csv',index=False)

# %%
# !git add matrix_one/day3.ipynb

# %%
# !git commit -m "read Men's Shoe Prices dataset from data.world"
# Out:
# [master 949e7eb] read Men's Shoe Prices dataset from data.world
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite matrix_one/day3.ipynb (97%)

# %%
 # !git config --global user.email "annatylenda@op.pl"
 # !git config --global user.name "Anna"

# %%
# !git push -u origin master
# Out:
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Everything up-to-date

# %%
'!git reset -hard <bb3228b70006f4606557d241763568b012abc604>'
# Out:
# '!git reset -hard <bb3228b70006f4606557d241763568b012abc604>'

# %%
`!git push -u origin master --force`
# Out:
#   File "<ipython-input-68-28abfa60ddae>", line 1
#     `!git push -u origin master --force`
#     ^
# SyntaxError: invalid syntax

# %%
'!git push -u origin master --force'
# Out:
# '!git push -u origin master --force'

# %%
'!git reset -hard <9389996f5c3c5dd29f2805dd232f21c8caba9bd5>'
# Out:
# '!git reset -hard <9389996f5c3c5dd29f2805dd232f21c8caba9bd5>'

# %%
`!git push -u origin master --force`
# Out:
#   File "<ipython-input-71-28abfa60ddae>", line 1
#     `!git push -u origin master --force`
#     ^
# SyntaxError: invalid syntax

# %%
'!git push -u origin master --force'
# Out:
# '!git push -u origin master --force'

# %%
# !git reset --hard 9389996f5c3c5dd29f2805dd232f21c8caba9bd5
# Out:
# HEAD is now at 9389996 add my first notebook - hello github

# %%
# !git push -u origin master --force
# Out:
# Total 0 (delta 0), reused 0 (delta 0)
# To https://github.com/AniaT/dw_matrix.git
#  + bb3228b...9389996 master -> master (forced update)
# Branch 'master' set up to track remote branch 'master' from 'origin'.
