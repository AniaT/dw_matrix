# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
cd "/content/drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/dw_matrix

# %%
df = pd.read_csv('data/men_shoes.csv',low_memory=False)
df.shape
# Out:
# (18280, 48)

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
mean_price = np.mean( df['prices_amountmin'] )
mean_price
# Out:
# 93.53952188183217

# %%
y_true = df['prices_amountmin']
y_pred = [mean_price] * y_true.shape[0]
mean_absolute_error(y_true,y_pred)
# Out:
# 63.968341227870624

# %%
y_true = df['prices_amountmin']
y_pred = [np.median(y_true)] * y_true.shape[0]

# %%
mean_absolute_error(y_true,y_pred)
# Out:
# 58.01120240700219

# %%
y_true = df['prices_amountmin']
price_log_mean = np.expm1( np.mean( np.log1p(y_true) ) )
y_pred = [price_log_mean] * y_true.shape[0]

mean_absolute_error(y_true,y_pred)
# Out:
# 58.03539547661041

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df['brand_cat'] = df['brand'].factorize()[0]

# %%
feats = ['brand_cat'] 
X = df[ feats ].values

# %%
y = df['prices_amountmin'].values
model = DecisionTreeRegressor(max_depth=5)
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
np.mean(scores), np.std(scores)
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
feats = ['brand_cat'] 
def run_model(feats):
  X = df[ feats ].values
  y = df['prices_amountmin'].values
  model = DecisionTreeRegressor(max_depth=5)
  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %%
run_model(['brand_cat'])
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
df['manufacturer_cat'] = df['manufacturer'].factorize()[0]

# %%
feats = ['manufacturer_cat'] 
X = df[ feats_col ].values

# %%
y = df['prices_amountmin'].values
model = DecisionTreeRegressor(max_depth=5)
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
np.mean(scores), np.std(scores)
# Out:
# (-63.133649278023746, 3.394307434888982)

# %%
feats= ['manufacturer_cat'] 
def run_model(feats_col):
  X = df[ feats_col ].values
  y = df['prices_amountmin'].values
  model = DecisionTreeRegressor(max_depth=5)
  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %%
run_model(['manufacturer_cat'])
# Out:
# (-63.133649278023746, 3.394307434888982)

# %%
run_model(['brand_cat', 'manufacturer_cat'])
# Out:
# (-58.539304199085976, 4.311223231615451)

# %%
# !git add dw_matrix/day4.ipynb
# Out:
# fatal: pathspec 'dw_matrix/day4.ipynb' did not match any files

# %%
ls
# Out:
# data/       day4_meta.ipynb    LICENSE      README.md
# day4.ipynb  HelloGitHub.ipynb  matrix_one/

# %%
# !git add day4.ipynb

# %%
# !git commit -m "first ML price prediction"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@628b688a37d9.(none)')

# %%
git config --global user.email "annatylenda@op.pl"
git config --global user.name "Anna"
# Out:
#   File "<ipython-input-108-b8afee20471e>", line 1
#     git config --global user.email "annatylenda@op.pl"
#              ^
# SyntaxError: invalid syntax

# %%
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://b892564d2e188dea4efaa5642620b4278a518e9c@github.com': No such device or address

# %%
GITHUB_TOKEN = '6aebcdb98b87773ec46de1801543dcbd4c1896f7'
GITHUB_URL = 'https://{0}@github.com/AniaT/dw_matrix.git'.format(GITHUB_TOKEN)

# %%
GITHUB_URL
# Out:
# 'https://6aebcdb98b87773ec46de1801543dcbd4c1896f7@github.com/AniaT/dw_matrix.git'

# %%
# !git clone {GITHUB_URL}
# Out:
# Cloning into 'dw_matrix'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 3), reused 7 (delta 1), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
ls
# Out:
# data/       day4_meta.ipynb  HelloGitHub.ipynb  matrix_one/
# day4.ipynb  dw_matrix/       LICENSE            README.md

# %%
# !git add day4.ipynb

# %%
# !git commit -m "first ML price prediction"
# Out:
# [master 7b93999] first ML price prediction
#  1 file changed, 1 insertion(+)
#  create mode 100644 day4.ipynb

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://b892564d2e188dea4efaa5642620b4278a518e9c@github.com': No such device or address

# %%
GITHUB_TOKEN = '97122ccbf4f546ba42dcbc9381a8a15819ed8124'

# %%
GITHUB_URL = 'https://{0}@github.com/AniaT/dw_matrix.git'.format(GITHUB_TOKEN)

# %%
# !git add day4.ipynb

# %%
# !git commit -m "first ML price prediction"
# Out:
# [master ead7063] first ML price prediction
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://b892564d2e188dea4efaa5642620b4278a518e9c@github.com': No such device or address
